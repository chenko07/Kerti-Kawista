# %%
#Library
import random
import math
import torch
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, random_split, DataLoader
from PIL import Image
import torchvision.transforms as T
# import tqdm
import time
import torch.nn as nn
from torchvision.utils import make_grid
# import re
import os
import requests
import matplotlib.pyplot as plt
import warnings
warnings.warn("ignore")
from torchvision import transforms
# Out:
# /var/folders/8x/1t17t31j0tz9cs952kyj6xf80000gp/T/ipykernel_62279/3792874269.py:19: UserWarning: ignore
#   warnings.warn("ignore")

# %%
class MyRegex:
    def search(self, pattern, text):
        # Implementasi pencarian pola dalam sebuah teks
        for i in range(len(text)):
            if text[i:i + len(pattern)] == pattern:
                return text[i:i + len(pattern)]
        return None

    def match(self, pattern, text):
        # Implementasi pencocokan pola hanya di awal teks
        if text.startswith(pattern):
            return pattern
        return None

    def findall(self, pattern, text):
        # Implementasi pencarian semua kemunculan pola dalam teks
        matches = []
        i = 0
        while i < len(text):
            match = self.match(pattern, text[i:])
            if match:
                matches.append(match)
                i += len(match)
            else:
                i += 1
        return matches

    def sub(self, pattern, replacement, text):
        # Implementasi penggantian pola dengan teks lain
        result = ""
        while True:
            match = self.search(pattern, text)
            if match:
                result += text[:text.index(match)] + replacement
                text = text[text.index(match) + len(match):]
            else:
                result += text
                break
        return result

# %%
class MyTqdm:
    def __init__(self, iterable, total=None, desc='', bar_length=40):
        self.iterable = iterable
        self.total = len(iterable) if total is None else total
        self.desc = desc
        self.bar_length = bar_length
        self.start_time = time.time()

    def __iter__(self):
        return self._generate()

    def _format_time(self, seconds):
        minutes, seconds = divmod(int(seconds), 60)
        hours, minutes = divmod(minutes, 60)
        return f'{hours:02}:{minutes:02}:{seconds:02}'

    def _progress_bar(self, iteration):
        progress = int(self.bar_length * iteration / max(self.total, 1))  # Handle division by 0
        return f"[{'=' * progress}{' ' * (self.bar_length - progress)}]"

    def _generate(self):
        print(f"{self.desc}: 0% {self._progress_bar(0)} 00:00:00", end='', flush=True)

        for i, item in enumerate(self.iterable, 1):
            yield item
            if i % (max(self.total // self.bar_length, 1)) == 0 or i == self.total:  # Handle division by 0
                elapsed_time = time.time() - self.start_time
                percentage = i / max(self.total, 1) * 100  # Handle division by 0
                remaining_time = (elapsed_time / max(i, 1)) * (max(self.total - i, 1))  # Handle division by 0
                print(f"\r{self.desc}: {percentage:.1f}% {self._progress_bar(i)} {self._format_time(elapsed_time)} / ETA {self._format_time(remaining_time)}", end='', flush=True)

        print("\n")

# %%
#Creating OS for Operating System Directory File
class MyOS:
    def __init__(self):
        self.current_directory = os.getcwd()

    def getcwd(self):
        return self.current_directory

    def chdir(self, path):
        if os.path.exists(path) and os.path.isdir(path):
            self.current_directory = path
        else:
            raise FileNotFoundError("Direktori tidak ditemukan.")

    def listdir(self, path='.'):
        full_path = os.path.join(self.current_directory, path)
        if os.path.exists(full_path) and os.path.isdir(full_path):
            return os.listdir(full_path)
        else:
            raise FileNotFoundError("Direktori tidak ditemukan.")

    def mkdir(self, path):
        full_path = os.path.join(self.current_directory, path)
        if not os.path.exists(full_path):
            os.mkdir(full_path)
        else:
            raise FileExistsError("Direktori sudah ada.")

    def rename(self, old, new):
        old_path = os.path.join(self.current_directory, old)
        new_path = os.path.join(self.current_directory, new)
        if os.path.exists(old_path):
            os.rename(old_path, new_path)
        else:
            raise FileNotFoundError("Path lama tidak ditemukan.")

    def remove(self, path):
        full_path = os.path.join(self.current_directory, path)
        if os.path.exists(full_path):
            os.remove(full_path)
        else:
            raise FileNotFoundError("Path tidak ditemukan.")

    def rmdir(self, path):
        full_path = os.path.join(self.current_directory, path)
        if os.path.exists(full_path) and os.path.isdir(full_path):
            os.rmdir(full_path)
        else:
            raise FileNotFoundError("Direktori tidak ditemukan atau bukan direktori kosong.")

    def exists(self, path):
        full_path = os.path.join(self.current_directory, path)
        return os.path.exists(full_path)

    def isfile(self, path):
        full_path = os.path.join(self.current_directory, path)
        return os.path.isfile(full_path)

    def isdir(self, path):
        full_path = os.path.join(self.current_directory, path)
        return os.path.isdir(full_path)

# %%
#Calling Dataset
data_directory = 'Equipment Recognition'
my_os = MyOS()

# %%
try:
    file_list = my_os.listdir(data_directory)
    print(file_list)
except FileNotFoundError as e:
    print(e)
# Out:
# ['Red_Helm', 'Orange_Helm', 'Yellow_Helm', 'White_Helm', 'Vest-samples']

# %%
def get_path_names(dir):
    images=[]
    for path, subdir, files in os.walk(data_directory):
        for name in files:
            images.append(os.path.join(path, name))
    return images

# %%
path = get_path_names(data_directory)

# %%
def get_path_names(root_dir):
    images=[]
    for root, _, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.jpg'):
                image_path = os.path.join(root, file)
                label = os.path.basename(root)
                images.append((image_path, label))
    return images

# %%
path[:3]
# Out:
# ['Equipment Recognition/Red_Helm/63.jpg',
#  'Equipment Recognition/Red_Helm/189.jpg',
#  'Equipment Recognition/Red_Helm/77.jpg']

# %%
classes = ['Red_Helm', 'Orange_Helm', 'Yellow_Helm', 'White_Helm', 'Vest-samples']

# %%
def encode_label(label, classes_list):
    if not isinstance(label, list):
        label = [label]
    target = torch.zeros(len(classes_list))
    for l in label:
        if l in classes_list:
            idx = classes_list.index(l)
            target[idx] = 1
    return target


def decode_target(target, threshold=0.5):
    if isinstance(target, list):
        result = ""
        for x in target:
            try:
                value = float(x)
                if value >= threshold:
                    result += "1"
                else:
                    result += "0"
            except ValueError:
                result += x
        return result
    else:
        try:
            value = float(target)
            if value >= threshold:
                return "1"
            else:
                return "0"
        except ValueError:
            return target

# %%
def get_classes(root_dir):
    classes = []
    for subdir in os.listdir(root_dir):
        if os.path.isdir(os.path.join(root_dir, subdir)):
            classes.append(subdir)
    return classes

# %%
class myDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.transform = transform
        self.root_dir = root_dir
        self.images = get_path_names(root_dir)
        self.classes = get_classes(root_dir)  # Get the list of class labels

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path, label = self.images[idx]
        img = Image.open(img_path)
        img = self.transform(img)

        print(f"Image Path: {img_path}")
        print(f"Label: {label}")

        return img, encode_label(label, classes_list=self.classes)

# %%
dataset = myDataset(root_dir = data_directory, transform=transforms.ToTensor())
len(dataset)
# Out:
# 3182

# %%
imagenet_stats = ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])

transform= transforms.Compose([T.Resize(128),
                      T.RandomCrop(128),
                      T.RandomHorizontalFlip(),
                      T.RandomRotation(2),
                      T.ToTensor(),
                      T.Normalize(*imagenet_stats)])

# %%
dataset = myDataset(data_directory, transform = transform)
len(dataset)
# Out:
# 3182

# %%
dataset[5]
# Out:
# Image Path: Equipment Recognition/Red_Helm/88.jpg
# Label: Red_Helm
# (tensor([[[-2.1179, -2.1179,  1.4098,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179,  0.8276,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179,  0.0912,  ...,  0.9817,  1.1358,  1.2557],
#           ...,
#           [ 0.1254,  0.1083,  0.1083,  ...,  0.9646, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ...,  0.9474, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ...,  0.9303, -2.1179, -2.1179]],
#
#          [[-2.0357, -2.0357,  1.5357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357,  0.8704,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357,  0.0651,  ...,  0.9580,  1.1331,  1.2906],
#           ...,
#           [ 0.1352,  0.1176,  0.1176,  ...,  0.9580, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ...,  0.9405, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ...,  0.9230, -2.0357, -2.0357]],
#
#          [[-1.8044, -1.8044,  1.4548,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044,  0.8099,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044,  0.0605,  ...,  0.7925,  0.8971,  0.9842],
#           ...,
#           [ 0.2522,  0.2348,  0.2348,  ...,  0.9145, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ...,  0.8971, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ...,  0.8797, -1.8044, -1.8044]]]),
#  tensor([1., 0., 0., 0., 0.]))

# %%
def denormalize(img_tensors): #Denormalize Image tensors
    return img_tensors * imagenet_stats[1][0] + imagenet_stats[0][0]

def show_examples(img, label):
    plt.imshow(denormalize(img).permute(1, 2, 0))
    print("Label:", decode_target(label))
    print()
    print(label)

show_examples(*dataset[655]) #mengambil contoh gambar yang sudah di tensor
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Image Path: Equipment Recognition/Orange_Helm/314.jpg
# Label: Orange_Helm
# Label: tensor([0., 1., 0., 0., 0.])
#
# tensor([0., 1., 0., 0., 0.])

# %%
validation_percent = int(0.10 *len(dataset))
train_size = len(dataset) - validation_percent
validation_size = len(dataset) - train_size
train_size, validation_size
# Out:
# (2864, 318)

# %%
train_datasplit, validation_datasplit = random_split(dataset, [train_size, validation_size]) #splitting the dataset for training and validation.
len(train_datasplit), len(validation_datasplit)
# Out:
# (2864, 318)

# %%
batch_size = 64
train_loader = DataLoader(train_datasplit, batch_size, shuffle=True)
validation_loader = DataLoader(validation_datasplit, batch_size * 2)

# %%
for xb, yb in train_loader:
    print(xb.shape)
    print(yb.shape)
    break
# Out:
# Image Path: Equipment Recognition/Yellow_Helm/413.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/64.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/282.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/351.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/93.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/721.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/193.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/332.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/188.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/354.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/345.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/337.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/194.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/276.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/165.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/469.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/7.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/347.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/393.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/39.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/237.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/642.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/367.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/34.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/15.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/223.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/309.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/209.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/170.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/215.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/474.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/596.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/8.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/366.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/340.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/687.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/12.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/91.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/3.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/379.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/840.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/845.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/3.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/233.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/858.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/334.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/510.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/411.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/174.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/287.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/451.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/446.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/30.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/85.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/1030.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/428.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/232.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/21.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/498.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/45.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/261.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/30.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/289.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/454.jpg
# Label: Orange_Helm
# torch.Size([64, 3, 128, 128])
# torch.Size([64, 5])

# %%
def show_batch_images(data, nmax=32):
    for images, labels in data:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]);
        ax.set_yticks([])
        ax.imshow(make_grid(denormalize(images[:nmax]), nrow=4).permute(1, 2, 0))
        break

show_batch_images(train_loader)
# Out:
# Image Path: Equipment Recognition/Vest-samples/766.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/209.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/871.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/831.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/203.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/209.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/393.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/119.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Orange_Helm/108.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/483.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/951.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/434.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/102.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/194.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/165.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/21.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/489.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/290.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/108.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/826.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/644.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/387.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/365.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/385.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/1100.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/695.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/111.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/270.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/139.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/142.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/344.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/504.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/155.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/284.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/139.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/51.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/492.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/264.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/442.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/230.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Orange_Helm/66.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/470.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/212.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/416.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/387.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/87.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/431.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/356.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/203.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/1102.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/371.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/473.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/43.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/128.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/300.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/149.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/151.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/379.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/873.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/514.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/83.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/438.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/6.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/131.jpg
# Label: Red_Helm
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def F_score(output, label, threshold=0.5, beta=1): #Calculate the accuracy of the model
    prob = output > threshold
    label = label > threshold

    TP = (prob & label).sum(1).float()
    TN = ((~prob) & (~label)).sum(1).float()
    FP = (prob & (~label)).sum(1).float()
    FN = ((~prob) & label).sum(1).float()

    precision = torch.mean(TP / (TP + FP + 1e-12))
    recall = torch.mean(TP / (TP + FN + 1e-12))
    F2 = (1 + beta**2) * precision * recall / (beta**2 * precision + recall + 1e-12)
    return F2.mean(0)

# %%
class MultilabelImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, targets = batch
        out = self(images)                            # Generate predictions
        loss = F.binary_cross_entropy(out, targets)   # Calculate loss
        return loss

    def validation_step(self, batch):
        images, targets = batch
        out = self(images)                           # Generate predictions
        loss = F.binary_cross_entropy(out, targets)  # Calculate loss
        score = F_score(out, targets)                # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_score': score.detach() }


    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()       # Combine losses and get the mean value
        batch_scores = [x['val_score'] for x in outputs]
        epoch_score = torch.stack(batch_scores).mean()      # Combine accuracies and get the mean value
        return {'val_loss': epoch_loss.item(), 'val_score': epoch_score.item()}

    def epoch_end(self, epoch, result):                     # display the losses
        print("Epoch [{}], last_lr: {:.4f}, train_loss: {:.4f}, val_loss: {:.4f}, val_score: {:.4f}"
              .format(epoch,
                      result['lrs'][-1],
                      result['train_loss'],
                      result['val_loss'],
                      result['val_score']))

# %%
# Fungsi untuk melakukan proses pada GPU
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')


def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

# %%
class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl:
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

device = get_default_device()
device
# Out:
# device(type='cpu')

# %%
train_dl = DeviceDataLoader(train_loader, device)
val_dl = DeviceDataLoader(validation_loader, device)

# %%
for xb, yb in train_dl:
    print(xb.shape)
    print(yb.shape)
    break
# Out:
# Image Path: Equipment Recognition/Vest-samples/858.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/397.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/345.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/341.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/97.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/428.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/607.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/277.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/393.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/177.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/57.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/5.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/793.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/145.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/304.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/407.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/187.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/155.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/625.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/349.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/190.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/503.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/131.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/26.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/16.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/90.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/125.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/429.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/951.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/276.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/487.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/5.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/595.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/928.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/671.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/350.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/191.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/77.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/206.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/46.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/76.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/19.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/306.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/163.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/140.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/510.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/330.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/634.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/325.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/363.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/21.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/276.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/370.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/338.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/444.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/152.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/1054.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/84.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/1039.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/178.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/48.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/29.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/846.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/799.jpg
# Label: Vest-samples
# torch.Size([64, 3, 128, 128])
# torch.Size([64, 5])

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)


def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_losses = []
        for batch in tqdm(train_loader):
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history


def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit_one_cycle(epochs, max_lr, model, train_loader, val_loader, weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []

    # Set up custom optimizer with weight decay
    optimizer = opt_func(model.parameters(), max_lr, weight_decay=weight_decay)
    # Set up one-cycle learning rate scheduler
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epochs, steps_per_epoch=len(train_loader)) #schedule the learning rate with OneCycleLR

    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_losses = []
        lrs = []
        for batch in MyTqdm(train_loader):
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()

            # Gradient clipping
            if grad_clip:
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)

            optimizer.step()
            optimizer.zero_grad()

            # Record & update learning rate
            lrs.append(get_lr(optimizer))
            sched.step()

        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['lrs'] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
def conv_block(in_channels, out_channels, pool=False):
    layers = [nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
              nn.BatchNorm2d(out_channels),
              nn.ReLU(inplace=True)]

    if pool: layers.append(nn.MaxPool2d(4))
    return nn.Sequential(*layers)


class ResNet15(MultilabelImageClassificationBase):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        #input 3 x 128 x 128
        self.conv1 = conv_block(in_channels, 64)  #output 64 x 128 x 128
        self.res1 = nn.Sequential(conv_block(64, 64), conv_block(64, 64)) #output 64 x 128 x 128


        self.conv2 = conv_block(64, 128, pool=True) #output 128 x 32 x 32
        self.res2 = nn.Sequential(conv_block(128, 128), conv_block(128, 128), conv_block(128, 128))  #output 128 x 32 x 32


        self.conv3 = conv_block(128, 512, pool=True) #output 512 x 8 x 8
        self.res3 = nn.Sequential(conv_block(512, 512), conv_block(512, 512)) #output 512 x 8 x 8


        self.conv4 = conv_block(512, 1024, pool=True) #output 1024 x 2 x 2
        self.res4 = nn.Sequential(conv_block(1024, 1024), conv_block(1024, 1024)) #output 1024 x 2 x 2


        self.classifier = nn.Sequential(nn.MaxPool2d(2), #output 1024 x 1 x 1
                                        nn.Flatten(),
                                        nn.Dropout(0.2),
                                        nn.Linear(1024 * 1 * 1, 512), #output 512
                                        nn.ReLU(),
                                        nn.Linear(512, num_classes)) #output 11

    def forward(self, xb):
        out = self.conv1(xb)
        out = self.res1(out) + out
        out = self.conv2(out)
        out = self.res2(out) + out
        out = self.conv3(out)
        out = self.res3(out) + out
        out = self.conv4(out)
        out = self.res4(out) + out
        out = self.classifier(out)
        out = F.sigmoid(out)
        return out

# %%
model = to_device(ResNet15(3, len(classes)), device) #input size: 3, output size: 11, loading model onto GPU
model
# Out:
# ResNet15(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (res1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res3): Sequential(
#     (0): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (conv4): Sequential(
#     (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res4): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=512, out_features=5, bias=True)
#   )
# )

# %%
import torch.nn.functional as F

# %%
for images, labels in train_dl:
    print(images.shape)
    outputs = model(images)
    break

print('outputs.shape : ', outputs.shape)
print('Sample outputs :\n', outputs[:2].data)
# Out:
# Image Path: Equipment Recognition/Orange_Helm/345.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/456.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/984.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/872.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/437.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/168.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/183.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/429.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/154.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/409.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/236.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/293.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/160.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/886.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/523.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/246.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/204.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/398.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/274.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/247.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/355.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/486.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/225.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/239.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/397.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/264.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/459.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/284.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/288.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/493.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/965.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/92.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/257.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/260.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/351.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/141.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/1044.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/515.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/337.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/131.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/296.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/1089.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/372.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/104.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/324.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/83.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/159.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/122.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/155.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/382.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/432.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/445.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/9.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/207.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/225.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/198.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/347.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/780.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/425.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/431.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/397.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/163.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/695.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/121.jpg
# Label: Vest-samples
# torch.Size([64, 3, 128, 128])
# outputs.shape :  torch.Size([64, 5])
# Sample outputs :
#  tensor([[0.4944, 0.5065, 0.5047, 0.5084, 0.5091],
#         [0.4935, 0.5045, 0.5053, 0.5083, 0.5103]])

# %%
history = [evaluate(model, val_dl)]
history
# Out:
# Image Path: Equipment Recognition/Vest-samples/761.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/46.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/26.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/796.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/445.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/425.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/433.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/84.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/6.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/150.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/55.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/1107.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/968.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/255.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/382.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/370.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/291.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/81.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/74.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/294.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/257.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/137.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/98.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/152.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/118.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/113.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Orange_Helm/50.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/392.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/263.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/479.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/298.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/63.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/24.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/369.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/183.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/345.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/166.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/88.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/475.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/485.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/368.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/342.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/664.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/197.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/384.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/464.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/704.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/188.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/816.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/641.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/225.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/270.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/196.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/56.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/410.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/188.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/83.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/67.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/475.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/299.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/719.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/234.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/229.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/868.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/146.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/300.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/901.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/628.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/482.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/467.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/468.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/404.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/480.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/218.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/220.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/952.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/857.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/166.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/161.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/409.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/316.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/368.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Orange_Helm/306.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/339.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/80.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/258.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/146.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/778.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/359.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/131.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/7.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/37.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/283.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/279.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/210.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/232.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/231.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/367.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/481.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/19.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/15.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/182.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/467.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/70.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/223.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/200.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/141.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/218.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/339.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/331.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/950.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/85.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/350.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/322.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/884.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/1019.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/270.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/994.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/494.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/441.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/726.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/118.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/448.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/491.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/214.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/408.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/647.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/185.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/81.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/353.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/148.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/389.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Orange_Helm/438.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/705.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/409.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/567.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/1021.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/856.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/180.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/421.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/303.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Orange_Helm/301.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/336.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Orange_Helm/383.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/304.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/477.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/65.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/236.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/1002.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/730.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/211.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/817.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/167.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/297.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/1055.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/425.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/198.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/482.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/966.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/273.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/328.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/238.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/41.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/160.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/46.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/119.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/308.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/41.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/377.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/312.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/681.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/485.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/1088.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/430.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/34.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/148.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/357.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/324.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/716.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/156.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/313.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/251.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/825.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/266.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/392.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/990.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/459.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/42.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/653.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/179.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/9.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/181.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/87.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/107.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/302.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/5.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/209.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/77.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/307.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Orange_Helm/358.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/317.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/100.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/168.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/381.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/159.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/298.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/496.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/97.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/158.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/359.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/1063.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/684.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/347.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/396.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/1096.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/408.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/24.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/464.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/201.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Red_Helm/442.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/256.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/440.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/246.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/69.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Orange_Helm/64.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/662.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/353.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Yellow_Helm/291.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/245.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/67.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/426.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/311.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/600.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/55.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples
jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/255.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/449.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/207.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/1049.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/458.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/58.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/253.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/29.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/465.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/518.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Orange_Helm/470.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/422.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Yellow_Helm/272.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Red_Helm/307.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/948.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/440.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/54.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/239.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/501.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Orange_Helm/246.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Red_Helm/430.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/White_Helm/514.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/100.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/185.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/352.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/124.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/369.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/593.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/234.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/178.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/470.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Red_Helm/60.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/198.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/222.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/443.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/541.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/344.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/38.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/305.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/307.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/332.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Yellow_Helm/43.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/Vest-samples/439.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/42.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/193.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Vest-samples/1087.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Vest-samples/174.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/3.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Yellow_Helm/240.jpg
# Label: Yellow_Helm
# Image Path: Equipment Recognition/White_Helm/187.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/381.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/1057.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Orange_Helm/337.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/352.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/White_Helm/29.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/723.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Red_Helm/268.jpg
# Label: Red_Helm
# Image Path: Equipment Recognition/Orange_Helm/272.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/White_Helm/123.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Orange_Helm/371.jpg
# Label: Orange_Helm
# Image Path: Equipment Recognition/Vest-samples/770.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/White_Helm/343.jpg
# Label: White_Helm
# Image Path: Equipment Recognition/Vest-samples/893.jpg
# Label: Vest-samples
# Image Path: Equipment Recognition/Yellow_Helm/121.jpg
# Label: Yellow_Helm
# Epoch [3], last_lr: 0.0000, train_loss: 0.0006, val_loss: 0.0001, val_score: 1.0000
# CPU times: user 7h 57min 7s, sys: 2h 37min 4s, total: 10h 34min 12s
# Wall time: 3h 15min 10s

# %%
def plot_scores(history):
    scores = [x['val_score'] for x in history]
    plt.plot(scores, '-x')
    plt.xlabel('epoch')
    plt.ylabel('score')
    plt.title('F1 score vs. No. of epochs');
    print(scores)
plot_scores(history)
# Out:
# [0.3462701737880707, 0.8197231292724609, 0.7238743305206299, 1.0, 1.0]

# %%
torch.save(model.state_dict(), 'model_equipment.pth')

# %%
def plot_lrs(history):
    lrs = np.concatenate([x.get('lrs', []) for x in history])
    plt.plot(lrs)
    plt.xlabel('Batch no.')
    plt.ylabel('Learning rate')
    plt.title('Learning Rate vs. Batch no.');
plot_lrs(history)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');
    
plot_losses(history)

# %%
def predict_single(image):
    xb = image.unsqueeze(0)
    xb = to_device(xb, device)
    preds = model(xb)
    prediction = preds[0]
    show_examples(image, prediction)
predict_single(validation_datasplit[84][0]) #checking out the predictions of some images from the validation dataset.
# Out:
# Image Path: Equipment Recognition/Orange_Helm/80.jpg
# Label: Orange_Helm
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: tensor([1.8624e-05, 9.9973e-01, 2.0537e-04, 3.6106e-04, 4.5144e-05],
#        grad_fn=<SelectBackward0>)
#
# tensor([1.8624e-05, 9.9973e-01, 2.0537e-04, 3.6106e-04, 4.5144e-05],
#        grad_fn=<SelectBackward0>)

# %%
def show_examples(image, prediction):
    # Lakukan post-processing pada hasil prediksi jika diperlukan
    # Misalnya, konversi dari tensor menjadi numpy array dan ambil indeks kelas dengan nilai tertinggi
    pred_class_index = torch.argmax(prediction).item()
    
    # Ambil nama kelas berdasarkan indeks kelas
    classes = ["alvian", "chen", "nicho", "rendie"]
    pred_class_name = classes[pred_class_index]

    # Tampilkan hasil prediksi
    print(f"Predicted class: {pred_class_name}")
    image.show()  # Menampilkan gambar dari kamera
